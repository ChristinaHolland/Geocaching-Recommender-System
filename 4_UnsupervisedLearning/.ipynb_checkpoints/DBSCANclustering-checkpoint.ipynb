# %% [markdown]
# ## DBSCAN Cluster Analysis

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
from sklearn.cluster import DBSCAN
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data0 = pd.read_csv('../data/working_files/data_withKMeans.csv')
data = data0.copy()
data.drop(columns=['KMeans cluster'])
data.head()
# Out:
#    good_logs_num  neutral_logs_num  bad_logs_num  difficulty  terrain  size  \
# 0              9                 0             1         2.0      1.5   1.0
# 1              1                 3             2         1.5      1.5   2.0
# 2              7                 2             0         1.5      1.5   2.0
# 3             10                 0             0         2.0      3.0   3.0
# 4              5                 2             0         1.5      2.5   1.0
#
#    status  is_premium  short_description  long_description  ...  \
# 0       1           1                  0                 1  ...
# 1       1           0                  0                 1  ...
# 2       1           0                  0                 1  ...
# 3       1           0                  1                 1  ...
# 4       1           0                  0                 1  ...
#
#    cache_type_Maze Exhibit  cache_type_Mega event  cache_type_Multi  \
# 0                        0                      0                 0
# 1                        0                      0                 0
# 2                        0                      0                 0
# 3                        0                      0                 0
# 4                        0                      0                 0
#
#    cache_type_Traditional  cache_type_Unknown/Mystery  cache_type_Virtual  \
# 0                       1                           0                   0
# 1                       1                           0                   0
# 2                       1                           0                   0
# 3                       0                           1                   0
# 4                       1                           0                   0
#
#    cache_type_Webcam  cache_type_Wherigo  sentiment  KMeans cluster
# 0                  0                   0     0.9730               1
# 1                  0                   0     0.9797              49
# 2                  0                   0    -0.9134              47
# 3                  0                   0     0.9958               2
# 4                  0                   0     0.9744               0
#
# [5 rows x 57 columns]

# %%
sc = StandardScaler()
X_sc = sc.fit_transform(data)

# %%
db = DBSCAN(eps=1.0, min_samples=4) #these are the defaults
db.fit(X_sc)

labels = db.labels_

sil = silhouette_score(X_sc, labels)
pct_noise = sum([1 for l in labels if l==-1])*100/data.shape[0]
num_clusters = np.max(labels)


print(f'Silhouette Score: {sil} with cache data.')
print(f'{num_clusters} clusters, + {pct_noise}% were NOT categorized.')
# Out:
# Silhouette Score: -0.021417778489332146 with cache data.
# 229 clusters, + 32.83197940963565% were NOT categorized.

# %%
chk = pd.DataFrame({'kmeans': list(data0['KMeans cluster']),'dbscan': labels})

capture_list = []
for c in range(labels.max()+1):
    num_dom = np.max(np.array(chk[chk['dbscan']==c]['kmeans'].value_counts()))
    num_all = chk[chk['dbscan']==c]['kmeans'].shape[0]
    cap=num_dom*100/num_all
    capture_list.append(cap)
avg_capture = np.mean(capture_list)

print(f'These clusters on average were {avg_capture} of their dominant kmeans cluster.')
# Out:
# These clusters on average were 99.42746345442846 of their dominant kmeans cluster.

# %% [markdown]
# #### Let's try a few different values for eps and min_samples:

# %%
def DBSCAN_gs(eps_list, n_list):
    
    kmeanlabels = list(data0['KMeans cluster'])
    scores = []
    for eps in eps_list:
        for min_samples in n_list:
            
            db = DBSCAN(eps=eps, min_samples=min_samples) #these are the defaults
            db.fit(X_sc)

            labels = db.labels_

            sil = silhouette_score(X_sc, labels)
            pct_noise = sum([1 for l in labels if l==-1])*100/data.shape[0]
            num_clusters = np.max(labels)

            chk = pd.DataFrame({'kmeans': kmeanlabels,'dbscan': labels})

            capture_list = []
            for c in range(labels.max()+1):
                num_dom = np.max(np.array(chk[chk['dbscan']==c]['kmeans'].value_counts()))
                num_all = chk[chk['dbscan']==c]['kmeans'].shape[0]
                cap=num_dom*100/num_all
                capture_list.append(cap)
            avg_capture = np.mean(capture_list)

            
            print(f'eps = {eps}, min_samples={min_samples}')
            print('--------------------------------------------------')
            print(f'Silhouette Score: {sil} with cache data.')
            print(f'{num_clusters} clusters, + {pct_noise}% were NOT categorized.')
            print(f'These clusters on average were {avg_capture} of their dominant kmeans cluster.')
            print()

            scores.append({
                'eps': eps,
                'min_samples': min_samples,
                'silhouette against data': sil,
                'number of clusters': num_clusters,
                'percent unclustered': pct_noise,
                'comparison against kmeans label': avg_capture
            })
    return scores

# %%
eps_list = [1, 2, 3, 4, 5]
n_list = [2, 3, 4, 5, 10]
scores1 = DBSCAN_gs(eps_list, n_list)
# Out:
# eps = 1, min_samples=2
# --------------------------------------------------
# Silhouette Score: 0.01745481196612966 with cache data.
# 611 clusters, + 24.676264779216602% were NOT categorized.
# These clusters on average were 99.77637507684172 of their dominant kmeans cluster.
#
# eps = 1, min_samples=3
# --------------------------------------------------
# Silhouette Score: -0.005879470981111998 with cache data.
# 340 clusters, + 29.03563098206386% were NOT categorized.
# These clusters on average were 99.74528312911183 of their dominant kmeans cluster.
#
# eps = 1, min_samples=4
# --------------------------------------------------
# Silhouette Score: -0.021417778489332146 with cache data.
# 229 clusters, + 32.83197940963565% were NOT categorized.
# These clusters on average were 99.42746345442846 of their dominant kmeans cluster.
#
# eps = 1, min_samples=5
# --------------------------------------------------
# Silhouette Score: -0.03290071928714871 with cache data.
# 180 clusters, + 35.78380117429422% were NOT categorized.
# These clusters on average were 99.55705240141437 of their dominant kmeans cluster.
#
# eps = 1, min_samples=10
# --------------------------------------------------
# Silhouette Score: -0.07803697884398653 with cache data.
# 101 clusters, + 45.186198021394674% were NOT categorized.
# These clusters on average were 99.93190465207444 of their dominant kmeans cluster.
#
# eps = 2, min_samples=2
# --------------------------------------------------
# Silhouette Score: 0.19863197543483238 with cache data.
# 347 clusters, + 7.51226574438993% were NOT categorized.
# These clusters on average were 99.44923944970846 of their dominant kmeans cluster.
#
# eps = 2, min_samples=3
# --------------------------------------------------
# Silhouette Score: 0.19168416798832674 with cache data.
# 234 clusters, + 9.330008847422183% were NOT categorized.
# These clusters on average were 99.3971716106321 of their dominant kmeans cluster.
#
# eps = 2, min_samples=4
# --------------------------------------------------
# Silhouette Score: 0.18975613036441635 with cache data.
# 194 clusters, + 10.882329284967426% were NOT categorized.
# These clusters on average were 99.27176619179376 of their dominant kmeans cluster.
#
# eps = 2, min_samples=5
# --------------------------------------------------
# Silhouette Score: 0.18534296028985187 with cache data.
# 167 clusters, + 12.217485723477841% were NOT categorized.
# These clusters on average were 99.1565532718462 of their dominant kmeans cluster.
#
# eps = 2, min_samples=10
# --------------------------------------------------
# Silhouette Score: 0.15991394674437043 with cache data.
# 99 clusters, + 17.718973699026783% were NOT categorized.
# These clusters on average were 98.76183314030614 of their dominant kmeans cluster.
#
# eps = 3, min_samples=2
# --------------------------------------------------
# Silhouette Score: 0.2764088847608637 with cache data.
# 138 clusters, + 2.726614654548379% were NOT categorized.
# These clusters on average were 99.15143542284055 of their dominant kmeans cluster.
#
# eps = 3, min_samples=3
# --------------------------------------------------
# Silhouette Score: 0.31370519535405883 with cache data.
# 97 clusters, + 3.3861497627282233% were NOT categorized.
# These clusters on average were 99.30662779362078 of their dominant kmeans cluster.
#
# eps = 3, min_samples=4
# --------------------------------------------------
# Silhouette Score: 0.30672328397750825 with cache data.
# 86 clusters, + 3.8285208718732404% were NOT categorized.
# These clusters on average were 99.2223849998788 of their dominant kmeans cluster.
#
# eps = 3, min_samples=5
# --------------------------------------------------
# Silhouette Score: 0.3101385873598074 with cache data.
# 75 clusters, + 4.33523686962117% were NOT categorized.
# These clusters on average were 99.11017501322631 of their dominant kmeans cluster.
#
# eps = 3, min_samples=10
# --------------------------------------------------
# Silhouette Score: 0.3055762685551946 with cache data.
# 59 clusters, + 6.177109305879514% were NOT categorized.
# These clusters on average were 99.00969491028064 of their dominant kmeans cluster.
#
# eps = 4, min_samples=2
# --------------------------------------------------
# Silhouette Score: 0.34025627584883694 with cache data.
# 87 clusters, + 1.294940883133596% were NOT categorized.
# These clusters on average were 99.14579754852315 of their dominant kmeans cluster.
#
# eps = 4, min_samples=3
# --------------------------------------------------
# Silhouette Score: 0.3459025418620769 with cache data.
# 68 clusters, + 1.6005791039974262% were NOT categorized.
# These clusters on average were 98.91058238072517 of their dominant kmeans cluster.
#
# eps = 4, min_samples=4
# --------------------------------------------------
# Silhouette Score: 0.34800973948694114 with cache data.
# 62 clusters, + 1.809699991956889% were NOT categorized.
# These clusters on average were 98.8069058284911 of their dominant kmeans cluster.
#
# eps = 4, min_samples=5
# --------------------------------------------------
# Silhouette Score: 0.3476246789677089 with cache data.
# 57 clusters, + 2.0509933242178073% were NOT categorized.
# These clusters on average were 98.70405288267136 of their dominant kmeans cluster.
#
# eps = 4, min_samples=10
# --------------------------------------------------
# Silhouette Score: 0.3482998463697363 with cache data.
# 47 clusters, + 2.8070457653020187% were NOT categorized.
# These clusters on average were 98.43374774203664 of their dominant kmeans cluster.
#
# eps = 5, min_samples=2
# --------------------------------------------------
# Silhouette Score: 0.42408914927203 with cache data.
# 58 clusters, + 0.659535108179844% were NOT categorized.
# These clusters on average were 98.44860500842285 of their dominant kmeans cluster.
#
# eps = 5, min_samples=3
# --------------------------------------------------
# Silhouette Score: 0.43083177610040346 with cache data.
# 48 clusters, + 0.820397329687123% were NOT categorized.
# These clusters on average were 98.131993785652 of their dominant kmeans cluster.
#
# eps = 5, min_samples=4
# --------------------------------------------------
# Silhouette Score: 0.4310404865554111 with cache data.
# 45 clusters, + 0.9169146625914903% were NOT categorized.
# These clusters on average were 98.01016729341191 of their dominant kmeans cluster.
#
# eps = 5, min_samples=5
# --------------------------------------------------
# Silhouette Score: 0.4330735486420228 with cache data.
# 42 clusters, + 1.0295182176465858% were NOT categorized.
# These clusters on average were 98.4527371045802 of their dominant kmeans cluster.
#
# eps = 5, min_samples=10
# --------------------------------------------------
# Silhouette Score: 0.4337460491278563 with cache data.
# 39 clusters, + 1.3110271052843239% were NOT categorized.
# These clusters on average were 98.33669238742371 of their dominant kmeans cluster.

# %%
pd.DataFrame(scores1).describe()
# Out:
#              eps  min_samples  silhouette against data  number of clusters  \
# count  25.000000     25.00000                25.000000           25.000000
# mean    3.000000      4.80000                 0.247999          140.400000
# std     1.443376      2.84312                 0.161582          132.142284
# min     1.000000      2.00000                -0.078037           39.000000
# 25%     2.000000      3.00000                 0.185343           58.000000
# 50%     3.000000      4.00000                 0.306723           87.000000
# 75%     4.000000      5.00000                 0.348010          180.000000
# max     5.000000     10.00000                 0.433746          611.000000
#
#        percent unclustered  comparison against kmeans label
# count            25.000000                        25.000000
# mean             10.397169                        99.026250
# std              12.893221                         0.518300
# min               0.659535                        98.010167
# 25%               1.600579                        98.704053
# 50%               3.828521                        99.145798
# 75%              12.217486                        99.397172
# max              45.186198                        99.931905

# %% [markdown]
# Very impressed with the match with KMeans! For all parameter values tested, the DBSCAN clusters were almost exclusively single KMeans Labels. Of course, many of them have a lot more clusters than kmeans did, which means this method is further dividing some of those clusters.

# %%
score1_df = pd.DataFrame(scores1)
score1_df.sort_values(by='silhouette against data', ascending=False).head()
# Out:
#     eps  min_samples  silhouette against data  number of clusters  \
# 24    5           10                 0.433746                  39
# 23    5            5                 0.433074                  42
# 22    5            4                 0.431040                  45
# 21    5            3                 0.430832                  48
# 20    5            2                 0.424089                  58
#
#     percent unclustered  comparison against kmeans label
# 24             1.311027                        98.336692
# 23             1.029518                        98.452737
# 22             0.916915                        98.010167
# 21             0.820397                        98.131994
# 20             0.659535                        98.448605

# %%
score1_df = pd.DataFrame(scores1)
score1_df.sort_values(by='percent unclustered', ascending=True).head()
# Out:
#     eps  min_samples  silhouette against data  number of clusters  \
# 20    5            2                 0.424089                  58
# 21    5            3                 0.430832                  48
# 22    5            4                 0.431040                  45
# 23    5            5                 0.433074                  42
# 15    4            2                 0.340256                  87
#
#     percent unclustered  comparison against kmeans label
# 20             0.659535                        98.448605
# 21             0.820397                        98.131994
# 22             0.916915                        98.010167
# 23             1.029518                        98.452737
# 15             1.294941                        99.145798

# %% [markdown]
# An eps value of 5 clearly beats the others, but this is the max I gave it before. I should extend that.
#
# I'll also extend the range of min_samples, on the higher end.
#
# I'll use silhouette as my metric, provided that the perrcent unclustered is also reasonable.

# %%
eps_list = [5, 6, 8, 10]
n_list = [2, 3, 4, 5, 6, 7, 8, 9, 10, 20]
scores2 = DBSCAN_gs(eps_list, n_list)
score2_df = pd.DataFrame(scores2)
score2_df.sort_values(by='silhouette against data', ascending=True).head()
# Out:
# eps = 5, min_samples=2
# --------------------------------------------------
# Silhouette Score: 0.42408914927203 with cache data.
# 58 clusters, + 0.659535108179844% were NOT categorized.
# These clusters on average were 98.44860500842285 of their dominant kmeans cluster.
#
# eps = 5, min_samples=3
# --------------------------------------------------
# Silhouette Score: 0.43083177610040346 with cache data.
# 48 clusters, + 0.820397329687123% were NOT categorized.
# These clusters on average were 98.131993785652 of their dominant kmeans cluster.
#
# eps = 5, min_samples=4
# --------------------------------------------------
# Silhouette Score: 0.4310404865554111 with cache data.
# 45 clusters, + 0.9169146625914903% were NOT categorized.
# These clusters on average were 98.01016729341191 of their dominant kmeans cluster.
#
# eps = 5, min_samples=5
# --------------------------------------------------
# Silhouette Score: 0.4330735486420228 with cache data.
# 42 clusters, + 1.0295182176465858% were NOT categorized.
# These clusters on average were 98.4527371045802 of their dominant kmeans cluster.
#
# eps = 5, min_samples=6
# --------------------------------------------------
# Silhouette Score: 0.43377533707447796 with cache data.
# 41 clusters, + 1.0938631062494972% were NOT categorized.
# These clusters on average were 98.4158975118321 of their dominant kmeans cluster.
#
# eps = 5, min_samples=7
# --------------------------------------------------
# Silhouette Score: 0.43285082153890225 with cache data.
# 40 clusters, + 1.166251105927773% were NOT categorized.
# These clusters on average were 98.37726086577922 of their dominant kmeans cluster.
#
# eps = 5, min_samples=8
# --------------------------------------------------
# Silhouette Score: 0.432720023066935 with cache data.
# 40 clusters, + 1.1903804391538648% were NOT categorized.
# These clusters on average were 98.37726086577922 of their dominant kmeans cluster.
#
# eps = 5, min_samples=9
# --------------------------------------------------
# Silhouette Score: 0.4325494006562545 with cache data.
# 40 clusters, + 1.2305959945306846% were NOT categorized.
# These clusters on average were 98.37726086577922 of their dominant kmeans cluster.
#
# eps = 5, min_samples=10
# --------------------------------------------------
# Silhouette Score: 0.4337460491278563 with cache data.
# 39 clusters, + 1.3110271052843239% were NOT categorized.
# These clusters on average were 98.33669238742371 of their dominant kmeans cluster.
#
# eps = 5, min_samples=20
# --------------------------------------------------
# Silhouette Score: 0.42967719605409893 with cache data.
# 37 clusters, + 1.7533982144293412% were NOT categorized.
# These clusters on average were 98.24925132457959 of their dominant kmeans cluster.
#
# eps = 6, min_samples=2
# --------------------------------------------------
# Silhouette Score: 0.42869351308877623 with cache data.
# 56 clusters, + 0.45041422022038125% were NOT categorized.
# These clusters on average were 98.81315144258349 of their dominant kmeans cluster.
#
# eps = 6, min_samples=3
# --------------------------------------------------
# Silhouette Score: 0.43283303689458963 with cache data.
# 48 clusters, + 0.5791039974262044% were NOT categorized.
# These clusters on average were 98.6193802495359 of their dominant kmeans cluster.
#
# eps = 6, min_samples=4
# --------------------------------------------------
# Silhouette Score: 0.43445667384458175 with cache data.
# 44 clusters, + 0.6917075524812998% were NOT categorized.
# These clusters on average were 98.50329187382594 of their dominant kmeans cluster.
#
# eps = 6, min_samples=5
# --------------------------------------------------
# Silhouette Score: 0.43472098564610817 with cache data.
# 42 clusters, + 0.7560524410842113% were NOT categorized.
# These clusters on average were 98.43367754237599 of their dominant kmeans cluster.
#
# eps = 6, min_samples=6
# --------------------------------------------------
# Silhouette Score: 0.4357226568058458 with cache data.
# 41 clusters, + 0.8043111075363951% were NOT categorized.
# These clusters on average were 98.40828891243257 of their dominant kmeans cluster.
#
# eps = 6, min_samples=7
# --------------------------------------------------
# Silhouette Score: 0.4350126887454758 with cache data.
# 40 clusters, + 0.8525697739885788% were NOT categorized.
# These clusters on average were 98.36946669078458 of their dominant kmeans cluster.
#
# eps = 6, min_samples=8
# --------------------------------------------------
# Silhouette Score: 0.4350126887454758 with cache data.
# 40 clusters, + 0.8525697739885788% were NOT categorized.
# These clusters on average were 98.36946669078458 of their dominant kmeans cluster.
#
# eps = 6, min_samples=9
# --------------------------------------------------
# Silhouette Score: 0.4350126887454758 with cache data.
# 40 clusters, + 0.8525697739885788% were NOT categorized.
# These clusters on average were 98.36946669078458 of their dominant kmeans cluster.
#
# eps = 6, min_samples=10
# --------------------------------------------------
# Silhouette Score: 0.4363515299055125 with cache data.
# 39 clusters, + 0.9330008847422183% were NOT categorized.
# These clusters on average were 98.32870335805418 of their dominant kmeans cluster.
#
# eps = 6, min_samples=20
# --------------------------------------------------
# Silhouette Score: 0.43383788404735024 with cache data.
# 37 clusters, + 1.1984235502292286% were NOT categorized.
# These clusters on average were 98.24074037689915 of their dominant kmeans cluster.
#
# eps = 8, min_samples=2
# --------------------------------------------------
# Silhouette Score: 0.49789421162011155 with cache data.
# 45 clusters, + 0.22520711011019062% were NOT categorized.
# These clusters on average were 98.48609376773754 of their dominant kmeans cluster.
#
# eps = 8, min_samples=3
# --------------------------------------------------
# Silhouette Score: 0.4982855108404808 with cache data.
# 39 clusters, + 0.32172444301455805% were NOT categorized.
# These clusters on average were 98.25900783289816 of their dominant kmeans cluster.
#
# eps = 8, min_samples=4
# --------------------------------------------------
# Silhouette Score: 0.49784748501760695 with cache data.
# 37 clusters, + 0.36998310946674173% were NOT categorized.
# These clusters on average were 98.1673766662086 of their dominant kmeans cluster.
#
# eps = 8, min_samples=5
# --------------------------------------------------
# Silhouette Score: 0.49751243528800654 with cache data.
# 36 clusters, + 0.40215555376819756% were NOT categorized.
# These clusters on average were 98.11784630583585 of their dominant kmeans cluster.
#
# eps = 8, min_samples=6
# --------------------------------------------------
# Silhouette Score: 0.49751243528800654 with cache data.
# 36 clusters, + 0.40215555376819756% were NOT categorized.
# These clusters on average were 98.11784630583585 of their dominant kmeans cluster.
#
# eps = 8, min_samples=7
# --------------------------------------------------
# Silhouette Score: 0.4967866802598815 with cache data.
# 35 clusters, + 0.45041422022038125% were NOT categorized.
# These clusters on average were 98.06556425877574 of their dominant kmeans cluster.
#
# eps = 8, min_samples=8
# --------------------------------------------------
# Silhouette Score: 0.4967866802598815 with cache data.
# 35 clusters, + 0.45041422022038125% were NOT categorized.
# These clusters on average were 98.06556425877574 of their dominant kmeans cluster.
#
# eps = 8, min_samples=9
# --------------------------------------------------
# Silhouette Score: 0.4967866802598815 with cache data.
# 35 clusters, + 0.45041422022038125% were NOT categorized.
# These clusters on average were 98.06556425877574 of their dominant kmeans cluster.
#
# eps = 8, min_samples=10
# --------------------------------------------------
# Silhouette Score: 0.4967866802598815 with cache data.
# 35 clusters, + 0.45041422022038125% were NOT categorized.
# These clusters on average were 98.06556425877574 of their dominant kmeans cluster.
#
# eps = 8, min_samples=20
# --------------------------------------------------
# Silhouette Score: 0.495380684043341 with cache data.
# 33 clusters, + 0.6836644414059359% were NOT categorized.
# These clusters on average were 97.95177392105667 of their dominant kmeans cluster.
#
# eps = 10, min_samples=2
# --------------------------------------------------
# Silhouette Score: 0.502005346301587 with cache data.
# 34 clusters, + 0.08043111075363951% were NOT categorized.
# These clusters on average were 97.94275811797714 of their dominant kmeans cluster.
#
# eps = 10, min_samples=3
# --------------------------------------------------
# Silhouette Score: 0.502108735054324 with cache data.
# 31 clusters, + 0.12868977720582322% were NOT categorized.
# These clusters on average were 97.7498916915375 of their dominant kmeans cluster.
#
# eps = 10, min_samples=4
# --------------------------------------------------
# Silhouette Score: 0.501897062949879 with cache data.
# 30 clusters, + 0.15281911043191507% were NOT categorized.
# These clusters on average were 97.67730755255484 of their dominant kmeans cluster.
#
# eps = 10, min_samples=5
# --------------------------------------------------
# Silhouette Score: 0.5018640963287143 with cache data.
# 30 clusters, + 0.16086222150727902% were NOT categorized.
# These clusters on average were 97.67730755255484 of their dominant kmeans cluster.
#
# eps = 10, min_samples=6
# --------------------------------------------------
# Silhouette Score: 0.5014303128246463 with cache data.
# 29 clusters, + 0.20107777688409878% were NOT categorized.
# These clusters on average were 97.59988447097334 of their dominant kmeans cluster.
#
# eps = 10, min_samples=7
# --------------------------------------------------
# Silhouette Score: 0.5014303128246463 with cache data.
# 29 clusters, + 0.20107777688409878% were NOT categorized.
# These clusters on average were 97.59988447097334 of their dominant kmeans cluster.
#
# eps = 10, min_samples=8
# --------------------------------------------------
# Silhouette Score: 0.5014303128246463 with cache data.
# 29 clusters, + 0.20107777688409878% were NOT categorized.
# These clusters on average were 97.59988447097334 of their dominant kmeans cluster.
#
# eps = 10, min_samples=9
# --------------------------------------------------
# Silhouette Score: 0.5014303128246463 with cache data.
# 29 clusters, + 0.20107777688409878% were NOT categorized.
# These clusters on average were 97.59988447097334 of their dominant kmeans cluster.
#
# eps = 10, min_samples=10
# --------------------------------------------------
# Silhouette Score: 0.5014303128246463 with cache data.
# 29 clusters, + 0.20107777688409878% were NOT categorized.
# These clusters on average were 97.59988447097334 of their dominant kmeans cluster.
#
# eps = 10, min_samples=20
# --------------------------------------------------
# Silhouette Score: 0.5004165146323735 with cache data.
# 28 clusters, + 0.3458537762406499% were NOT categorized.
# These clusters on average were 97.51706869985655 of their dominant kmeans cluster.
#     eps  min_samples  silhouette against data  number of clusters  \
# 0     5            2                 0.424089                  58
# 10    6            2                 0.428694                  56
# 9     5           20                 0.429677                  37
# 1     5            3                 0.430832                  48
# 2     5            4                 0.431040                  45
#
#     percent unclustered  comparison against kmeans label
# 0              0.659535                        98.448605
# 10             0.450414                        98.813151
# 9              1.753398                        98.249251
# 1              0.820397                        98.131994
# 2              0.916915                        98.010167

# %%
score2_df.describe()
# Out:
#             eps  min_samples  silhouette against data  number of clusters  \
# count  40.00000    40.000000                40.000000           40.000000
# mean    7.25000     7.400000                 0.466076           38.025000
# std     1.94475     4.924038                 0.033798            6.988956
# min     5.00000     2.000000                 0.424089           28.000000
# 25%     5.75000     4.000000                 0.433578           33.750000
# 50%     7.00000     6.500000                 0.465866           38.000000
# 75%     8.50000     9.000000                 0.498818           41.000000
# max    10.00000    20.000000                 0.502109           58.000000
#
#        percent unclustered  comparison against kmeans label
# count            40.000000                        40.000000
# mean              0.630580                        98.138968
# std               0.404929                         0.333651
# min               0.080431                        97.517069
# 25%               0.297595                        97.949520
# 50%               0.514759                        98.204059
# 75%               0.868656                        98.377261
# max               1.753398                        98.813151

# %% [markdown]
# These clusters are still lining up really well with the kmeans clusters, just breaking them into smaller pieces.
#
# #### Setting eps = 5 and min_samples = 2

# %%
db = DBSCAN(eps=5.0, min_samples=2) 
db.fit(X_sc)

labels = db.labels_

sil = silhouette_score(X_sc, labels)
pct_noise = sum([1 for l in labels if l==-1])*100/data.shape[0]
num_clusters = np.max(labels)

kmeanlabels = list(data0['KMeans cluster'])
chk = pd.DataFrame({'kmeans': kmeanlabels,'dbscan': labels})

capture_list = []
for c in range(labels.max()+1):
    num_dom = np.max(np.array(chk[chk['dbscan']==c]['kmeans'].value_counts()))
    num_all = chk[chk['dbscan']==c]['kmeans'].shape[0]
    cap=num_dom*100/num_all
    capture_list.append(cap)
avg_capture = np.mean(capture_list)

print(f'These clusters on average were {avg_capture} of their dominant kmeans cluster.')
print(f'Silhouette Score: {sil} with cache data.')
print(f'{num_clusters} clusters, + {pct_noise}% were NOT categorized.')
# Out:
# These clusters on average were 98.44860500842285 of their dominant kmeans cluster.
# Silhouette Score: 0.42408914927203 with cache data.
# 58 clusters, + 0.659535108179844% were NOT categorized.

# %% [markdown]
# Note, this is better than the best silhouette score for kmeans, which was 0.335615866756178.

# %%
data_old = pd.read_csv('../data/working_files/strippeddata.csv')
data_old['DBSCAN cluster'] = labels
data_old.to_csv('../data/working_files/data_withDBSCAN.csv',index=False)

# %%
clabels = [-1] + list(range(labels.max()+1))
captures = [0] + capture_list
cnt = [chk[chk['dbscan']==c]['kmeans'].shape[0] for c in clabels]
clabels[0] = 'noise'

# %%
chk1 = pd.DataFrame({
    'cluster': clabels,
    'caches within': cnt,
    'homogeneity': captures
})
chk1.sort_values(by='homogeneity').head()
# Out:
#    cluster  caches within  homogeneity
# 0    noise             82     0.000000
# 1        0           8683    33.467695
# 28      27              4    75.000000
# 32      31              2   100.000000
# 33      32              2   100.000000

# %%
chk[chk['dbscan']==0]['kmeans'].value_counts()
# Out:
# 0     2906
# 40    1406
# 2      965
# 1      821
# 49     758
# 45     725
# 28     468
# 46     467
# 47     167
# Name: kmeans, dtype: int64

# %%
chk[chk['dbscan']==0]['kmeans'].value_counts().sum()*100/data_old.shape[0]
# Out:
# 69.83833346738518

# %%
2906/2908
# Out:
# 0.9993122420907841

# %%
chk[chk['dbscan']==27]['kmeans'].value_counts()
# Out:
# 33    3
# 47    1
# Name: kmeans, dtype: int64

# %%
2908/data_old.shape[0]
# Out:
# 0.23389367007158368

# %%
chk[chk['dbscan']==0]['kmeans'].value_counts().sum()-2908
# Out:
# 5775

# %% [markdown]
# The DBSCAN clusters map directly to single KMeans clusters, EXCEPT for DBSCAN clusters 1 and 27.
#
# Several KMeans clusters have been split into 2 or more DBSCANS clusters.
#
# DBSCAN cluster #27 is just 4 caches, and 3 of them are the same KMeans label.
#
# The only real issue is with DBSCAN cluster #0, with includes 99.9% of the KMeans cluster 0, which was already the largest cluster in KMeans, with 23.4% of the caches, PLUS another 5575 caches split among 8 other Kmeans clusters. Altogether, DBSCAN cluster #0 is 69.8% of the caches.

# %%
print('| DBSCAN cluster | number of caches | homogeneity |')
print('|--- |--- |--- |')
for j in list(range(0,60)):
    print(f'| {list(chk1.loc[j])[0]} | {list(chk1.loc[j])[1]} | {list(chk1.loc[j])[2]} |')
# Out:
# | DBSCAN cluster | number of caches | homogeneity |
# |--- |--- |--- |
# | noise | 82 | 0.0 |
# | 0 | 8683 | 33.46769549694806 |
# | 1 | 70 | 100.0 |
# | 2 | 159 | 100.0 |
# | 3 | 65 | 100.0 |
# | 4 | 131 | 100.0 |
# | 5 | 2 | 100.0 |
# | 6 | 350 | 100.0 |
# | 7 | 152 | 100.0 |
# | 8 | 87 | 100.0 |
# | 9 | 50 | 100.0 |
# | 10 | 48 | 100.0 |
# | 11 | 62 | 100.0 |
# | 12 | 3 | 100.0 |
# | 13 | 9 | 100.0 |
# | 14 | 56 | 100.0 |
# | 15 | 108 | 100.0 |
# | 16 | 2 | 100.0 |
# | 17 | 78 | 100.0 |
# | 18 | 5 | 100.0 |
# | 19 | 85 | 100.0 |
# | 20 | 3 | 100.0 |
# | 21 | 60 | 100.0 |
# | 22 | 4 | 100.0 |
# | 23 | 3 | 100.0 |
# | 24 | 50 | 100.0 |
# | 25 | 195 | 100.0 |
# | 26 | 14 | 100.0 |
# | 27 | 4 | 75.0 |
# | 28 | 65 | 100.0 |
# | 29 | 2 | 100.0 |
# | 30 | 58 | 100.0 |
# | 31 | 2 | 100.0 |
# | 32 | 2 | 100.0 |
# | 33 | 88 | 100.0 |
# | 34 | 49 | 100.0 |
# | 35 | 2 | 100.0 |
# | 36 | 52 | 100.0 |
# | 37 | 59 | 100.0 |
# | 38 | 331 | 100.0 |
# | 39 | 46 | 100.0 |
# | 40 | 4 | 100.0 |
# | 41 | 179 | 100.0 |
# | 42 | 103 | 100.0 |
# | 43 | 15 | 100.0 |
# | 44 | 114 | 100.0 |
# | 45 | 102 | 100.0 |
# | 46 | 168 | 100.0 |
# | 47 | 62 | 100.0 |
# | 48 | 48 | 100.0 |
# | 49 | 52 | 100.0 |
# | 50 | 25 | 100.0 |
# | 51 | 60 | 100.0 |
# | 52 | 2 | 100.0 |
# | 53 | 6 | 100.0 |
# | 54 | 2 | 100.0 |
# | 55 | 73 | 100.0 |
# | 56 | 38 | 100.0 |
# | 57 | 2 | 100.0 |
# | 58 | 2 | 100.0 |

# %% [markdown]
# #### Summary:
#
# With the defaults of eps=1.0, min_samples=4:
#
# Silhouette Score: -0.021417778489332146 with cache data.
# 229 clusters, + 32.83197940963565% were NOT categorized.
# These clusters on average were 99.42746345442846 of their dominant kmeans cluster.
#
# Manual gridsearch over eps_list = [1, 2, 3, 4, 5] and n_list = [2, 3, 4, 5, 10],
#
# then over eps_list = [5, 6, 8, 10], n_list = [2, 3, 4, 5, 6, 7, 8, 9, 10, 20]
#
# Very impressed with the match with KMeans! For all parameter values tested, the DBSCAN clusters were almost exclusively single KMeans Labels. Of course, many of them have a lot more clusters than kmeans did, which means this method is further dividing some of those clusters.
#
# Selected eps = 5 and min_samples = 2 on the basis of maximum silhouette and minimum percent noise.
#
# These clusters on average were 98.44860500842285 of their dominant kmeans cluster.
# Silhouette Score: 0.42408914927203 with cache data.
# 58 clusters, + 0.659535108179844% were NOT categorized.
#
# Note, this is better than the best silhouette score for kmeans, which was 0.335615866756178.
#
# And the number of clusters is comparable to kmeans (58 vs 50).
#
# | DBSCAN cluster | number of caches | homogeneity |
# |--- |--- |--- |
# | noise | 82 | 0.0 |
# | 0 | 8683 | 33.46769549694806 |
# | 1 | 70 | 100.0 |
# | 2 | 159 | 100.0 |
# | 3 | 65 | 100.0 |
# | 4 | 131 | 100.0 |
# | 5 | 2 | 100.0 |
# | 6 | 350 | 100.0 |
# | 7 | 152 | 100.0 |
# | 8 | 87 | 100.0 |
# | 9 | 50 | 100.0 |
# | 10 | 48 | 100.0 |
# | 11 | 62 | 100.0 |
# | 12 | 3 | 100.0 |
# | 13 | 9 | 100.0 |
# | 14 | 56 | 100.0 |
# | 15 | 108 | 100.0 |
# | 16 | 2 | 100.0 |
# | 17 | 78 | 100.0 |
# | 18 | 5 | 100.0 |
# | 19 | 85 | 100.0 |
# | 20 | 3 | 100.0 |
# | 21 | 60 | 100.0 |
# | 22 | 4 | 100.0 |
# | 23 | 3 | 100.0 |
# | 24 | 50 | 100.0 |
# | 25 | 195 | 100.0 |
# | 26 | 14 | 100.0 |
# | 27 | 4 | 75.0 |
# | 28 | 65 | 100.0 |
# | 29 | 2 | 100.0 |
# | 30 | 58 | 100.0 |
# | 31 | 2 | 100.0 |
# | 32 | 2 | 100.0 |
# | 33 | 88 | 100.0 |
# | 34 | 49 | 100.0 |
# | 35 | 2 | 100.0 |
# | 36 | 52 | 100.0 |
# | 37 | 59 | 100.0 |
# | 38 | 331 | 100.0 |
# | 39 | 46 | 100.0 |
# | 40 | 4 | 100.0 |
# | 41 | 179 | 100.0 |
# | 42 | 103 | 100.0 |
# | 43 | 15 | 100.0 |
# | 44 | 114 | 100.0 |
# | 45 | 102 | 100.0 |
# | 46 | 168 | 100.0 |
# | 47 | 62 | 100.0 |
# | 48 | 48 | 100.0 |
# | 49 | 52 | 100.0 |
# | 50 | 25 | 100.0 |
# | 51 | 60 | 100.0 |
# | 52 | 2 | 100.0 |
# | 53 | 6 | 100.0 |
# | 54 | 2 | 100.0 |
# | 55 | 73 | 100.0 |
# | 56 | 38 | 100.0 |
# | 57 | 2 | 100.0 |
# | 58 | 2 | 100.0 |
#
# The DBSCAN clusters map directly to single KMeans clusters, EXCEPT for DBSCAN clusters 1 and 27.
#
# Several KMeans clusters have been split into 2 or more DBSCANS clusters.
#
# DBSCAN cluster #27 is just 4 caches, and 3 of them are the same KMeans label.
#
# The only real issue is with DBSCAN cluster #0, with includes 99.9% of the KMeans cluster 0, which was already the largest cluster in KMeans, with 23.4% of the caches, PLUS another 5575 caches split among 8 other Kmeans clusters. Altogether, DBSCAN cluster #0 is 69.8% of the caches.
